# %%
# import required libraries

import pandas as pd

# %%
# import the dataset

df = pd.read_csv('Product Reviews.csv')

# %%
df.head()
# Out:
#          brand manufacturer  \
# 0    Microsoft    Microsoft
# 1         Sony         Sony
# 2         Sony         Sony
# 3  Sling Media     Slingbox
# 4      Midland      Midland
#
#                                                 name primaryCategories  \
# 0  Microsoft Surface Pro 4 Type Cover with Finger...       Electronics
# 1  Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charc...       Electronics
# 2   Sony Mini Digital Video Cassettes - DVC - 1 Hour       Electronics
# 3                                        Slingbox M2       Electronics
# 4                Midland Weather Alert Radio, 1.0 CT       Electronics
#
#   reviews.date  reviews.rating  \
# 0   2015-10-29               0
# 1   2017-01-16               5
# 2   2016-09-12               5
# 3   2017-03-19               4
# 4   2017-02-17               5
#
#                                         reviews.text reviews.username
# 0  I've had this keyboard case for a day. I figur...      Reviewer101
# ...

# %%
# explore the dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              382 non-null    object
#  1   manufacturer       382 non-null    object
#  2   name               382 non-null    object
#  3   primaryCategories  382 non-null    object
#  4   reviews.date       382 non-null    object
#  5   reviews.rating     382 non-null    int64
#  6   reviews.text       382 non-null    object
#  7   reviews.username   382 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 24.0+ KB

# %%
# to get the info about the shape of the dataframe

df.shape
# Out:
# (382, 8)

# %%
# lets convert reviews.date column to proper date format

df['reviews.date'] = pd.to_datetime(df['reviews.date'])

# %%
# lets check if review.date is converted to date format

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 382 entries, 0 to 381
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              382 non-null    object
#  1   manufacturer       382 non-null    object
#  2   name               382 non-null    object
#  3   primaryCategories  382 non-null    object
#  4   reviews.date       382 non-null    datetime64[ns]
#  5   reviews.rating     382 non-null    int64
#  6   reviews.text       382 non-null    object
#  7   reviews.username   382 non-null    object
# dtypes: datetime64[ns](1), int64(1), object(6)
# memory usage: 24.0+ KB

# %%
# to see out of total 382 rows, which brand has how many rows

df['brand'].value_counts()
# Out:
# Sling Media               197
# Sony                      147
# Midland                    30
# Microsoft                   2
# Verizon Wireless            2
# Lenovo                      2
# Sdi Technologies, Inc.      1
# Boytone                     1
# Name: brand, dtype: int64

# %%
# to see out of total 382 rows, which rating has how many rows

df['reviews.rating'].value_counts()
# Out:
# 5    230
# 4    102
# 1     21
# 3     18
# 2      8
# 0      3
# Name: reviews.rating, dtype: int64

# %% [markdown]
# ### convert reviews to upper or lower case

# %%
# convert reviews to lower case

df['reviews.text']
# Out:
# 0      I've had this keyboard case for a day. I figur...
# 1      Went into the store with a different speaker i...
# 2           They work good on my camera it's a good make
# 3      Streaming requires high speed internet and a s...
# 4      We recently moved to FL from NY and our new ne...
#                              ...
# 377    We had an older sling box and worked ok but th...
# 378    Great speaker for a great price! You will not ...
# 379    Could not program the radio as directed, nor w...
# 380    This is a great price for multi pack of tapes ...
# 381    Purchased this in hopes that someone could set...
# Name: reviews.text, Length: 382, dtype: object

# %%
df['reviews.text'].str.lower()
# Out:
# 0      i've had this keyboard case for a day. i figur...
# 1      went into the store with a different speaker i...
# 2           they work good on my camera it's a good make
# 3      streaming requires high speed internet and a s...
# 4      we recently moved to fl from ny and our new ne...
#                              ...
# 377    we had an older sling box and worked ok but th...
# 378    great speaker for a great price! you will not ...
# 379    could not program the radio as directed, nor w...
# 380    this is a great price for multi pack of tapes ...
# 381    purchased this in hopes that someone could set...
# Name: reviews.text, Length: 382, dtype: object

# %%
# convert reviews to upper case

df['reviews.text'].str.upper()
# Out:
# 0      I'VE HAD THIS KEYBOARD CASE FOR A DAY. I FIGUR...
# 1      WENT INTO THE STORE WITH A DIFFERENT SPEAKER I...
# 2           THEY WORK GOOD ON MY CAMERA IT'S A GOOD MAKE
# 3      STREAMING REQUIRES HIGH SPEED INTERNET AND A S...
# 4      WE RECENTLY MOVED TO FL FROM NY AND OUR NEW NE...
#                              ...
# 377    WE HAD AN OLDER SLING BOX AND WORKED OK BUT TH...
# 378    GREAT SPEAKER FOR A GREAT PRICE! YOU WILL NOT ...
# 379    COULD NOT PROGRAM THE RADIO AS DIRECTED, NOR W...
# 380    THIS IS A GREAT PRICE FOR MULTI PACK OF TAPES ...
# 381    PURCHASED THIS IN HOPES THAT SOMEONE COULD SET...
# Name: reviews.text, Length: 382, dtype: object

# %% [markdown]
# ### use of replace method

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
df.head()
# Out:
#          brand manufacturer  \
# 0    Microsoft    Microsoft
# 1         Sony         Sony
# 2         Sony         Sony
# 3  Sling Media     Slingbox
# 4      Midland      Midland
#
#                                                 name primaryCategories  \
# 0  Microsoft Surface Pro 4 Type Cover with Finger...       Electronics
# 1  Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charc...       Electronics
# 2   Sony Mini Digital Video Cassettes - DVC - 1 Hour       Electronics
# 3                                        Slingbox M2       Electronics
# 4                        Midland Weather Alert Radio       Electronics
#
#   reviews.date  reviews.rating  \
# 0   2015-10-29               0
# 1   2017-01-16               5
# 2   2016-09-12               5
# 3   2017-03-19               4
# 4   2017-02-17               5
#
#                                         reviews.text reviews.username
# 0  I've had this keyboard case for a day. I figur...      Reviewer101
# ...

# %%
df['name'] = df['name'].str.replace('Midland Weather Alert Radio, 1.0 CT', 'Midland Weather Alert Radio')

# %%
df['name'].head()
# Out:
# 0    Microsoft Surface Pro 4 Type Cover with Finger...
# 1    Sony SRSHG1/BLK Hi-Res Wireless Speaker- Charc...
# 2     Sony Mini Digital Video Cassettes - DVC - 1 Hour
# 3                                          Slingbox M2
# 4                          Midland Weather Alert Radio
# Name: name, dtype: object

# %% [markdown]
# ### String functions

# %%
dir('hello')
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'removeprefix',
#  'removesuffix',
#  'replace',
# ...

# %%
# to see how many times a word is coming in each value of the string

df['reviews.text'].str.count('good')
# Out:
# 0      0
# 1      0
# 2      2
# 3      0
# 4      0
#       ..
# 377    0
# 378    0
# 379    0
# 380    0
# 381    1
# Name: reviews.text, Length: 382, dtype: int64

# %%
# to filter the rows which have good in the string atleast once

df[df['reviews.text'].str.count('good')>0]
# Out:
#                 brand manufacturer  \
# 2                Sony         Sony
# 15               Sony         Sony
# 29               Sony         Sony
# 38               Sony         Sony
# 43        Sling Media     Slingbox
# 46               Sony         Sony
# 47               Sony         Sony
# 56        Sling Media     Slingbox
# 58               Sony         Sony
# 62        Sling Media     Slingbox
# 64               Sony         Sony
# 69   Verizon Wireless      Novatel
# 70               Sony         Sony
# 72        Sling Media     Slingbox
# 75               Sony         Sony
# 81               Sony         Sony
# 82        Sling Media     Slingbox
# 96               Sony         Sony
# 97        Sling Media     Slingbox
# 100              Sony         Sony
# 102              Sony         Sony
# 111       Sling Media     Slingbox
# 124              Sony         Sony
# 130              Sony         Sony
# 149       Sling Media     Slingbox
# ...

# %%
len(df[df['reviews.text'].str.count('good')>0])
# Out:
# 58

# %%
df.loc[df['reviews.text'].str.startswith('good'),'reviews.text']
# Out:
# Series([], Name: reviews.text, dtype: object)

# %%
df[df['reviews.text'].str.contains('good')]
# Out:
#                 brand manufacturer  \
# 2                Sony         Sony
# 15               Sony         Sony
# 29               Sony         Sony
# 38               Sony         Sony
# 43        Sling Media     Slingbox
# 46               Sony         Sony
# 47               Sony         Sony
# 56        Sling Media     Slingbox
# 58               Sony         Sony
# 62        Sling Media     Slingbox
# 64               Sony         Sony
# 69   Verizon Wireless      Novatel
# 70               Sony         Sony
# 72        Sling Media     Slingbox
# 75               Sony         Sony
# 81               Sony         Sony
# 82        Sling Media     Slingbox
# 96               Sony         Sony
# 97        Sling Media     Slingbox
# 100              Sony         Sony
# 102              Sony         Sony
# 111       Sling Media     Slingbox
# 124              Sony         Sony
# 130              Sony         Sony
# 149       Sling Media     Slingbox
# ...
